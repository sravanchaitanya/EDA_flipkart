# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('phones1.csv'))

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Brand              Model          Colour  \
# 0           0             0  Apple  iPhone 11 Pro Max  Midnight Green
# 1           1             1  Apple  iPhone 11 Pro Max          Silver
# 2           2             2  Apple  iPhone 11 Pro Max      Space Grey
# 3           3             3  Apple          iPhone 5C             NaN
# 4           4             4  Apple          iPhone 6s      Space Grey
#
#   Touchscreen  Display(cm) Operating System Internal Storage   RAM  ...  \
# 0         Yes        16.51           iOS 13           512 GB  4 GB  ...
# 1         Yes        16.51           iOS 13           512 GB  4 GB  ...
# 2         Yes        16.51           iOS 13           512 GB  4 GB  ...
# 3         Yes        10.16            iOS 7             8 GB  1 GB  ...
# 4         Yes        11.94            iOS 9            64 GB  2 GB  ...
#
#    Total 3star ratings  Total 2star ratings  Total 1star ratings  \
# ...

# %%
df.drop(df.columns[0],inplace = True,axis = 1)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Brand              Model          Colour Touchscreen  \
# 0             0  Apple  iPhone 11 Pro Max  Midnight Green         Yes
# 1             1  Apple  iPhone 11 Pro Max          Silver         Yes
# 2             2  Apple  iPhone 11 Pro Max      Space Grey         Yes
# 3             3  Apple          iPhone 5C             NaN         Yes
# 4             4  Apple          iPhone 6s      Space Grey         Yes
#
#    Display(cm) Operating System Internal Storage   RAM  Primary Camera  ...  \
# 0        16.51           iOS 13           512 GB  4 GB            36.0  ...
# 1        16.51           iOS 13           512 GB  4 GB            36.0  ...
# 2        16.51           iOS 13           512 GB  4 GB            36.0  ...
# 3        10.16            iOS 7             8 GB  1 GB             8.0  ...
# 4        11.94            iOS 9            64 GB  2 GB            12.0  ...
#
#    Total 3star ratings  Total 2star ratings  Total 1star ratings  \
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Colour', 'Touchscreen', 'Display(cm)',
#        'Operating System', 'Internal Storage', 'RAM', 'Primary Camera',
#        'Battery Capacity', 'width(mm)', 'Height(mm)', 'Weight(g)',
#        'Overall Rating', 'Total 5star ratings', 'Total 4star ratings',
#        'Total 3star ratings', 'Total 2star ratings', 'Total 1star ratings',
#        'Camera Rating', 'Battery Rating', 'Display Rating', 'Design Rating',
#        'Total Ratings', 'Total Reviews', 'Price'],
#       dtype='object')

# %%
df.drop(df.columns[0],axis = 1,inplace = True)

# %%
df.Colour = df.Colour.apply(lambda x: 'Red' if x=='(PRODUCT)RED' else x)

# %%
df.Colour.unique()
# Out:
# array(['Midnight Green', 'Silver', 'Space Grey', nan, 'Black', 'Gold',
#        'Blue', 'Red', 'White', 'Rose Gold', 'Jet Black', 'Graphite',
#        'Yellow', 'Green', 'Space Gray', 'Alpine Green', 'Grey', 'Coral',
#        'Purple', 'Pacific Blue', 'Starlight', 'Midnight', 'Sierra Blue',
#        'Deep Purple', 'Space Black', 'Pink', 'Twilight', 'Emerald Green',
#        'NA', 'CELESTIAL SILVER', 'Mystic Silver', 'Titanium Grey',
#        'Prestige Gold', 'Peacock Blue', 'Midnight Black',
#        'MIDNIGHT BLACK', 'Pearl White', 'Robin Egg Blue', 'Phantom Red',
#        'Mystery Grey', 'Phantom Purple', 'Sapphire Blue', 'Navy Blue',
#        'Phantom Blue', 'Fantasy Silver', 'Sky Blue', 'Sunrise Gold',
#        'Aurora Blue', 'Glacier Grey', 'Graphite Black', 'Black/White',
#        'Chromatic Blue', 'LEGEND', 'Dynamo black', 'Tornado Black',
#        'Solid Ice Blue', 'Sunset Sierra', 'Cyber Blue', 'Ace Black',
# ...

# %%
df.Colour = df.Colour.apply(lambda x: 'NA' if pd.isnull(x) else x)

# %%
df['Display(cm)'].unique()
# Out:
# array([16.51, 10.16, 11.94, 15.49, 14.73, 17.02, 13.97, 13.94, 8.89,
#        13.72, 15.5, 16.23, 14.48, 6.1, 11.43, 7.11, 8.13, 9.65, 11.35,
#        6.6, 16.74, 12.7, 16.94, 13.21, 15.62, 15.06, 13.84, 16.0, 14.83,
#        15.21, 15.77, 15.9, 14.35, 14.99, 16.71, 17.22, 16.36, 16.81,
#        16.97, 16.66, 15.46, 16.54, 16.64, 15.75, 4.57, 16.26, 16.43,
#        16.76, 17.0, 17.27, 15.24, 15.7, 13.46, 7.62, 10.9, 14.5, 9.68,
#        10.92, 9.4, 'NA', 7.09, 16.69, 17.32, 16.33, 16.28, 16.59, 16.56,
#        15.8, 4.5, 13.08, 8.1, 7.98, 10.41, 17.78, 15.44, 17.09, 50.8,
#        5.08, 14.22, 19.3, 16.55, 3.81, 17.53, 5.16, 3.86, 8.38, 5.59,
#        6.48, 12.19, 11.68, 17.4, 17.65, 16.89, 167.64, 16.13, 16.21],
#       dtype=object)

# %%
df['Display(cm)'] = df['Display(cm)'].apply(lambda x: 'NA' if pd.isnull(x) else x)

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Colour', 'Touchscreen', 'Display(cm)',
#        'Operating System', 'Internal Storage', 'RAM', 'Primary Camera',
#        'Battery Capacity', 'width(mm)', 'Height(mm)', 'Weight(g)',
#        'Overall Rating', 'Total 5star ratings', 'Total 4star ratings',
#        'Total 3star ratings', 'Total 2star ratings', 'Total 1star ratings',
#        'Camera Rating', 'Battery Rating', 'Display Rating', 'Design Rating',
#        'Total Ratings', 'Total Reviews', 'Price'],
#       dtype='object')

# %%
df['Operating System'].unique()
# Out:
# array(['iOS 13', 'iOS 7', 'iOS 9', 'iOS 11', 'iOS 14', 'iOS 14.2',
#        'iOS 8', 'iOS 12', 'iOS 15', 'iOS 16', 'Android Pie EMUI V9',
#        'Android Marshmallow 6', 'Android Jelly Bean 4.2.2',
#        'Android Gingerbread 2.3', nan, 'Android Ice Cream Sandwich 4',
#        'Android Froyo 2.2', 'Android Jelly Bean 4.2',
#        'Android Eclair 2.1', 'Android Pie 9', 'Android Nougat 11',
#        'Android Gingerbread 2.3.6', 'Android Pie 9.0', 'Android Nougat 7',
#        'Android Lollipop 5.1', 'Android KitKat 4.4', 'Android 10',
#        'Android Oreo 8', 'Android Oreo 8.1.0', 'Android Marshmallow v6.0',
#        'Android Oreo 8.1', 'Android Oreo v8.1', 'Android Lollipop 5',
#        'Android Oreo EMUI 8.2 based on Android 8.1', 'Android Q 11',
#        'Android Q 12', 'Android Funtouch OS 12 based on Android 12',
#        'Android Lollipop 5.1.1', 'Android 11', 'Android Nougat 7.1',
#        'Android KitKat 4.4.4', 'Android 12', 'Android Nougat 7.1.1',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3137 entries, 0 to 3136
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                3137 non-null   object
#  1   Model                3137 non-null   object
#  2   Colour               3137 non-null   object
#  3   Touchscreen          3137 non-null   object
#  4   Display(cm)          3137 non-null   object
#  5   Operating System     3010 non-null   object
#  6   Internal Storage     3080 non-null   object
#  7   RAM                  3045 non-null   object
#  8   Primary Camera       2976 non-null   float64
#  9   Battery Capacity     2683 non-null   float64
#  10  width(mm)            2477 non-null   float64
#  11  Height(mm)           2486 non-null   float64
#  12  Weight(g)            2400 non-null   float64
#  13  Overall Rating       2725 non-null   float64
#  14  Total 5star ratings  2527 non-null   object
# ...

# %%
df.Touchscreen.fillna('NA',inplace = True)

# %%
df[df['Operating System'].isnull()]
# Out:
#          Brand            Model     Colour Touchscreen Display(cm)  \
# 475     HUAWEI             Y600         NA          NA         6.1
# 478     HUAWEI            G7010         NA         Yes        7.11
# 481     HUAWEI            U5510         NA          NA         6.1
# 765   MOTOROLA              a10  Dark Blue         Yes        4.57
# 769   MOTOROLA              a10  Rose Gold         Yes        4.57
# ...        ...              ...        ...         ...         ...
# 2707      SONY       Yari U100i         NA          NA         6.1
# 2708      SONY            Spiro         NA          NA        5.59
# 2709      SONY             W705         NA          NA         6.1
# 2710      SONY            Cedar         NA          NA        5.59
# 2757      SONY  SmartBand SWR10         NA          NA          NA
#
#      Operating System Internal Storage     RAM  Primary Camera  \
# 475               NaN             4 GB     NaN             NaN
# ...

# %%
df = df[df['Operating System'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3010 entries, 0 to 3136
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                3010 non-null   object
#  1   Model                3010 non-null   object
#  2   Colour               3010 non-null   object
#  3   Touchscreen          3010 non-null   object
#  4   Display(cm)          3010 non-null   object
#  5   Operating System     3010 non-null   object
#  6   Internal Storage     2997 non-null   object
#  7   RAM                  2986 non-null   object
#  8   Primary Camera       2938 non-null   float64
#  9   Battery Capacity     2590 non-null   float64
#  10  width(mm)            2432 non-null   float64
#  11  Height(mm)           2440 non-null   float64
#  12  Weight(g)            2340 non-null   float64
#  13  Overall Rating       2618 non-null   float64
#  14  Total 5star ratings  2432 non-null   object
# ...

# %%
df[df['Battery Capacity'].isnull()]
# Out:
#      Brand              Model          Colour Touchscreen Display(cm)  \
# 0    Apple  iPhone 11 Pro Max  Midnight Green         Yes       16.51
# 1    Apple  iPhone 11 Pro Max          Silver         Yes       16.51
# 2    Apple  iPhone 11 Pro Max      Space Grey         Yes       16.51
# 5    Apple          iPhone 11           Black         Yes       15.49
# 6    Apple           iPhone X          Silver         Yes       14.73
# ..     ...                ...             ...         ...         ...
# 465  Apple          iPhone 11           White         Yes       15.49
# 466  Apple          iPhone 11          Yellow         Yes       15.49
# 467  Apple          iPhone 13            Blue         Yes       15.49
# 468  Apple          iPhone 13       Starlight         Yes       15.49
# 469  Apple          iPhone 13        Midnight         Yes       15.49
#
#     Operating System Internal Storage   RAM  Primary Camera  Battery Capacity  \
# ...
